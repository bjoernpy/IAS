# %% [markdown]
# # Aufgabe 1.4

# %%
import numpy as np
import pandas as pd
from time import perf_counter
from random import randint
from V1A2_Classifier import *

# %%
# (I) Load data 
forestdata  = pd.read_csv('../DATA/ForestTypes/ForestTypesData.csv'); # load data as pandas data frame 
classlabels = ['s','h','d','o'];                                      # possible class labels (C=4) 
classidx    = {classlabels[i]:i for i in range(len(classlabels))}     # dict for mapping classlabel to index 
C           = len(classlabels)        # number of classes (Note: K is now the number of nearest-neighbors!!!!!!)
T_txt = forestdata.values[:,0]        # array of class labels of data vectors (class label is first data attribute)
X = forestdata.values[:,1:]           # array of feature vectors (features are remaining attributes)
T = [classidx[t.strip()] for t in T_txt]          # transform text labels 's','h','d','o' to numeric lables 0,1,2,3
N,D=X.shape                           # size and dimensionality of data set
print("Data set 'ForestData' has size N=", N, " and dimensionality D=",D, " and C=", C, " different classes")
print("X[0..9]=\n",X[0:10])
print("T_txt[0..9]=\n",T_txt[0:10])
print("T[0..9]=\n",T[0:10])
# Out:
# Data set 'ForestData' has size N= 523  and dimensionality D= 27  and C= 4  different classes
# X[0..9]=
#  [[39 36 57 91 59 101 93 27 60 75.7 14.86 40.35 7.97 -32.92 -38.92 -14.94
#   4.47 -2.36 -18.41 -1.88 -6.43 -21.03 -1.6 -6.18 -22.5 -5.2 -7.86]
#  [84 30 57 112 51 98 92 26 62 30.58 20.42 39.83 -16.74 -24.92 -36.33
#   -15.67 8.16 -2.26 -16.27 -1.95 -6.25 -18.79 -1.99 -6.18 -23.41 -8.87
#   -10.83]
#  [53 25 49 99 51 93 84 26 58 63.2 26.7 49.28 3.25 -24.89 -30.38 -3.6 4.15
#   -1.46 -15.92 -1.79 -4.64 -17.73 -0.48 -4.69 -19.97 -4.1 -7.07]
#  [59 26 49 103 47 92 82 25 56 55.54 24.5 47.9 -6.2 -20.98 -30.28 -5.03
#   7.77 2.68 -13.77 -2.53 -6.34 -22.03 -2.34 -6.6 -27.1 -7.99 -10.81]
#  [57 49 66 103 64 106 114 28 59 59.44 2.62 32.02 -1.33 -37.99 -43.57
#   -34.25 1.83 -2.94 -21.74 -1.64 -4.62 -23.74 -0.85 -5.5 -22.83 -2.74
#   -5.84]
#  [85 28 56 120 52 98 101 27 65 35.14 23.43 42.29 -16.58 -25.43 -34.14
#   -17.45 1.58 -10.28 -26.18 -1.89 -5.89 -34.92 -1.89 -8.05 -29.72 -1.94
#   -4.94]
#  [56 29 50 93 51 94 77 26 58 62.5 22.48 48.2 9.69 -24.78 -30.81 3.91 3.09
#   -2.68 -26.33 -0.55 -3.89 -23.84 0.02 -4.2 -23.17 -0.22 -4.22]
#  [40 39 58 82 61 99 89 26 57 73.99 12.91 41.92 17.33 -34.82 -36.19 -11.07
#   4.28 -0.19 -18.72 -2.61 -8.38 -20.56 -1.51 -6.68 -21.16 -3.42 -6.61]
#  [53 27 49 95 49 92 63 25 54 66.97 24.43 49.28 8.08 -22.53 -28.25 19.78
#   3.75 0.92 -25.65 -2.09 -5.95 -39.27 -2.13 -8.73 -30.73 -2.42 -5.58]
#  [51 57 77 90 89 123 97 47 83 64.91 -5.21 21.45 12.21 -62.9 -60.4 -16.75
#   -16.85 -26.44 -20.97 -1.76 -5.05 -22.01 -0.93 -5.6 -22.26 -3.28 -6.39]]
# T_txt[0..9]=
#  ['d ' 'h ' 's ' 's ' 'd ' 'h ' 's ' 'd ' 's ' 'o ']
# T[0..9]=
#  [2, 1, 0, 0, 2, 1, 0, 2, 0, 3]

# %% [markdown]
# # a) und b)

# %%
# (II) Test KNN-classifier with S-fold cross validation
S_list=[5]                         # parameter S for cross validation; INSERT appropriate values
K_list=[3]                            # number K of nearest neighbors; INSERT appropriate values
accuracy = np.zeros((len(S_list),len(K_list)));   # array to save accuracy of classifier for each value of S and K
for i in range(len(S_list)):
    S=S_list[i]                      # do an S-fold cross validation
    for j in range(len(K_list)):
        K=K_list[j]
        t1=perf_counter()                   # start time
        knnc = FastKNNClassifier(C,K)                            # REPLACE! create appropriate KNN classifier (with kd-trees) 
        pE,pCE = knnc.crossvalidate(S,X,T)                          # REPLACE! Do S-fold cross validation and get error probabilities / confusion matrix
        t2=perf_counter()                            # end time
        time_comp=t2-t1                       # computing time in seconds
        print("\nS=",S," fold cross validation using the",K,"-NNClassifier with KD-Trees yields the following results:")
        print("Classification error probability = ", pE)
        print("Accuracy = ", 1.0-pE)
        print("Confusion Error Probabilities p(class i|class j) = \n", pCE)
        print("Computing time = ", time_comp, " sec")
        accuracy[i,j]=1.0-pE
print("\naccuracy=\n",accuracy)
print("\np_classerror=\n",1.0-accuracy)
# Out:
# S= 5  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.45124282982791586
# Accuracy =  0.5487571701720841
# Confusion Error Probabilities p(class i|class j) =
#  [[0.18974359 0.02325581 0.12578616 0.03614458]
#  [0.21538462 0.89534884 0.06289308 0.19277108]
#  [0.24102564 0.02325581 0.75471698 0.13253012]
#  [0.35384615 0.05813953 0.05660377 0.63855422]]
# Computing time =  2.2980376  sec
#
# accuracy=
#  [[0.54875717]]
#
# p_classerror=
#  [[0.45124283]]

# %% [markdown]
# # c)

# %%
S_list=[1,2,3,5,10,100]                         # parameter S for cross validation; INSERT appropriate values
K_list=[2,3,5,15,100]                          # number K of nearest neighbors; INSERT appropriate values
accuracy = np.zeros((len(S_list),len(K_list)));   # array to save accuracy of classifier for each value of S and K
for i in range(len(S_list)):
    S=S_list[i]                      # do an S-fold cross validation
    for j in range(len(K_list)):
        K=K_list[j]
        t1=perf_counter()                   # start time
        knnc = FastKNNClassifier(C,K)                            # REPLACE! create appropriate KNN classifier (with kd-trees) 
        pE,pCE = knnc.crossvalidate(S,X,T)                          # REPLACE! Do S-fold cross validation and get error probabilities / confusion matrix
        t2=perf_counter()                            # end time
        time_comp=t2-t1                       # computing time in seconds
        print("\nS=",S," fold cross validation using the",K,"-NNClassifier with KD-Trees yields the following results:")
        print("Classification error probability = ", pE)
        print("Accuracy = ", 1.0-pE)
        print("Confusion Error Probabilities p(class i|class j) = \n", pCE)
        print("Computing time = ", time_comp, " sec")
        accuracy[i,j]=1.0-pE
print("\naccuracy=\n",accuracy)
print("\np_classerror=\n",1.0-accuracy)
# Out:
# S= 1  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.5525812619502868
# Accuracy =  0.4474187380497132
# Confusion Error Probabilities p(class i|class j) =
#  [[0.         0.01162791 0.         0.        ]
#  [0.         0.88372093 0.00628931 0.80722892]
#  [1.         0.10465116 0.99371069 0.19277108]
#  [0.         0.         0.         0.        ]]
# Computing time =  2.126216  sec
#
# S= 1  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8432122370936902
# Accuracy =  0.1567877629063098
# Confusion Error Probabilities p(class i|class j) =
#  [[0.02564103 0.70930233 0.62264151 0.12048193]
#  [0.96923077 0.06976744 0.03144654 0.02409639]
#  [0.         0.         0.         0.        ]
#  [0.00512821 0.22093023 0.34591195 0.85542169]]
# Computing time =  2.3579205000000005  sec
#
# S= 1  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.5793499043977055
# Accuracy =  0.4206500956022945
# Confusion Error Probabilities p(class i|class j) =
#  [[0.         0.         0.         0.        ]
#  [0.92820513 0.06976744 0.05031447 0.01204819]
#  [0.02051282 0.         0.91194969 0.15662651]
#  [0.05128205 0.93023256 0.03773585 0.8313253 ]]
# Computing time =  2.686582999999999  sec
#
# S= 1  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6424474187380497
# Accuracy =  0.35755258126195033
# Confusion Error Probabilities p(class i|class j) =
#  [[0.01538462 0.46511628 0.04402516 0.36144578]
#  [0.9025641  0.09302326 0.06289308 0.02409639]
#  [0.04615385 0.18604651 0.88679245 0.19277108]
#  [0.03589744 0.25581395 0.00628931 0.42168675]]
# Computing time =  3.2866954999999987  sec
#
# S= 1  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.5181644359464627
# Accuracy =  0.48183556405353734
# Confusion Error Probabilities p(class i|class j) =
#  [[0.93333333 0.1744186  0.96855346 0.39759036]
#  [0.06153846 0.76744186 0.00628931 0.01204819]
#  [0.00512821 0.05813953 0.02515723 0.59036145]
#  [0.         0.         0.         0.        ]]
# Computing time =  5.216363800000002  sec
#
# S= 2  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6940726577437859
# Accuracy =  0.3059273422562141
# Confusion Error Probabilities p(class i|class j) =
#  [[0.18461538 0.1744186  0.16352201 0.03614458]
#  [0.00512821 0.09302326 0.         0.28915663]
#  [0.51282051 0.20930233 0.49685535 0.22891566]
#  [0.2974359  0.52325581 0.33962264 0.44578313]]
# Computing time =  1.4580052000000023  sec
#
# S= 2  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8260038240917782
# Accuracy =  0.1739961759082218
# Confusion Error Probabilities p(class i|class j) =
#  [[0.3025641  0.05813953 0.2327044  0.04819277]
#  [0.18461538 0.01162791 0.18238994 0.81927711]
#  [0.2974359  0.88372093 0.14465409 0.03614458]
#  [0.21538462 0.04651163 0.44025157 0.09638554]]
# Computing time =  1.7014840000000007  sec
#
# S= 2  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.5391969407265774
# Accuracy =  0.4608030592734226
# Confusion Error Probabilities p(class i|class j) =
#  [[0.34358974 0.06976744 0.19496855 0.07228916]
#  [0.32307692 0.88372093 0.18867925 0.02409639]
#  [0.33333333 0.04651163 0.6163522  0.90361446]
#  [0.         0.         0.         0.        ]]
# Computing time =  2.042333599999999  sec
#
# S= 2  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.875717017208413
# Accuracy =  0.124282982791587
# Confusion Error Probabilities p(class i|class j) =
#  [[0.06666667 0.65116279 0.66037736 0.37349398]
#  [0.         0.         0.         0.        ]
#  [0.92820513 0.23255814 0.23899371 0.45783133]
#  [0.00512821 0.11627907 0.10062893 0.1686747 ]]
# Computing time =  2.308040300000002  sec
#
# S= 2  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.780114722753346
# Accuracy =  0.21988527724665397
# Confusion Error Probabilities p(class i|class j) =
#  [[0.01538462 0.         0.         0.        ]
#  [0.04102564 0.26744186 0.3081761  0.44578313]
#  [0.4        0.18604651 0.5408805  0.51807229]
#  [0.54358974 0.54651163 0.1509434  0.03614458]]
# Computing time =  3.2189671000000004  sec
#
# S= 3  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7151051625239006
# Accuracy =  0.28489483747609945
# Confusion Error Probabilities p(class i|class j) =
#  [[0.02051282 0.46511628 0.13207547 0.03614458]
#  [0.61025641 0.1627907  0.22012579 0.26506024]
#  [0.02564103 0.13953488 0.58490566 0.24096386]
#  [0.34358974 0.23255814 0.06289308 0.45783133]]
# Computing time =  1.9378681000000029  sec
#
# S= 3  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8432122370936902
# Accuracy =  0.1567877629063098
# Confusion Error Probabilities p(class i|class j) =
#  [[0.12820513 0.03488372 0.44654088 0.27710843]
#  [0.10769231 0.55813953 0.22012579 0.61445783]
#  [0.         0.         0.         0.        ]
#  [0.76410256 0.40697674 0.33333333 0.10843373]]
# Computing time =  1.9867956000000007  sec
#
# S= 3  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7112810707456979
# Accuracy =  0.2887189292543021
# Confusion Error Probabilities p(class i|class j) =
#  [[0.66153846 0.77906977 0.64150943 0.61445783]
#  [0.01538462 0.20930233 0.         0.        ]
#  [0.         0.         0.00628931 0.34939759]
#  [0.32307692 0.01162791 0.35220126 0.03614458]]
# Computing time =  2.180819900000003  sec
#
# S= 3  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7304015296367112
# Accuracy =  0.26959847036328877
# Confusion Error Probabilities p(class i|class j) =
#  [[0.05128205 0.54651163 0.21383648 0.18072289]
#  [0.28717949 0.1744186  0.05660377 0.53012048]
#  [0.66153846 0.27906977 0.72955975 0.28915663]
#  [0.         0.         0.         0.        ]]
# Computing time =  2.9429225000000017  sec
#
# S= 3  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7437858508604207
# Accuracy =  0.2562141491395793
# Confusion Error Probabilities p(class i|class j) =
#  [[0.66666667 0.41860465 0.91194969 0.90361446]
#  [0.         0.         0.         0.08433735]
#  [0.02564103 0.52325581 0.01886792 0.        ]
#  [0.30769231 0.05813953 0.06918239 0.01204819]]
# Computing time =  4.191869599999997  sec
#
# S= 5  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.9292543021032504
# Accuracy =  0.07074569789674956
# Confusion Error Probabilities p(class i|class j) =
#  [[0.         0.         0.02515723 0.34939759]
#  [0.15384615 0.02325581 0.72327044 0.44578313]
#  [0.00512821 0.         0.16981132 0.10843373]
#  [0.84102564 0.97674419 0.08176101 0.09638554]]
# Computing time =  2.087286899999995  sec
#
# S= 5  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6959847036328872
# Accuracy =  0.3040152963671128
# Confusion Error Probabilities p(class i|class j) =
#  [[0.02051282 0.         0.00628931 0.        ]
#  [0.07179487 0.19767442 0.19496855 0.06024096]
#  [0.86666667 0.80232558 0.77987421 0.77108434]
#  [0.04102564 0.         0.01886792 0.1686747 ]]
# Computing time =  2.3625194999999977  sec
#
# S= 5  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6328871892925431
# Accuracy =  0.36711281070745694
# Confusion Error Probabilities p(class i|class j) =
#  [[0.35897436 0.02325581 0.30188679 0.06024096]
#  [0.         0.         0.         0.        ]
#  [0.31282051 0.93023256 0.40880503 0.25301205]
#  [0.32820513 0.04651163 0.28930818 0.68674699]]
# Computing time =  2.4336058000000023  sec
# S= 5  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8910133843212237
# Accuracy =  0.10898661567877632
# Confusion Error Probabilities p(class i|class j) =
#  [[0.04615385 0.69767442 0.69811321 0.24096386]
#  [0.         0.         0.         0.        ]
#  [0.95384615 0.30232558 0.30188679 0.75903614]
#  [0.         0.         0.         0.        ]]
# Computing time =  3.132790700000001  sec
#
# S= 5  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.722753346080306
# Accuracy =  0.27724665391969405
# Confusion Error Probabilities p(class i|class j) =
#  [[0.03076923 0.18604651 0.14465409 0.34939759]
#  [0.         0.         0.         0.        ]
#  [0.96923077 0.81395349 0.85534591 0.61445783]
#  [0.         0.         0.         0.03614458]]
# Computing time =  4.710222099999996  sec
#
# S= 10  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6749521988527725
# Accuracy =  0.32504780114722753
# Confusion Error Probabilities p(class i|class j) =
#  [[0.02564103 0.         0.10062893 0.30120482]
#  [0.77435897 0.06976744 0.06289308 0.06024096]
#  [0.17435897 0.90697674 0.81761006 0.28915663]
#  [0.02564103 0.02325581 0.01886792 0.34939759]]
# Computing time =  2.248293199999999  sec
#
# S= 10  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8986615678776291
# Accuracy =  0.10133843212237093
# Confusion Error Probabilities p(class i|class j) =
#  [[0.         0.22093023 0.0754717  0.09638554]
#  [0.05641026 0.5        0.86163522 0.87951807]
#  [0.93333333 0.11627907 0.06289308 0.02409639]
#  [0.01025641 0.1627907  0.         0.        ]]
# Computing time =  2.3743942999999987  sec
#
# S= 10  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.9770554493307839
# Accuracy =  0.02294455066921608
# Confusion Error Probabilities p(class i|class j) =
#  [[0.01538462 0.         0.90566038 0.89156627]
#  [0.         0.         0.         0.        ]
#  [0.1025641  0.06976744 0.00628931 0.01204819]
#  [0.88205128 0.93023256 0.08805031 0.09638554]]
# Computing time =  2.6434757000000033  sec
#
# S= 10  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.8049713193116634
# Accuracy =  0.19502868068833656
# Confusion Error Probabilities p(class i|class j) =
#  [[0.05641026 0.48837209 0.37106918 0.09638554]
#  [0.90769231 0.15116279 0.13836478 0.03614458]
#  [0.03589744 0.36046512 0.49056604 0.86746988]
#  [0.         0.         0.         0.        ]]
# Computing time =  3.3580439999999925  sec
#
# S= 10  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7915869980879541
# Accuracy =  0.20841300191204593
# Confusion Error Probabilities p(class i|class j) =
#  [[0.02051282 0.1744186  0.67295597 0.63855422]
#  [0.06153846 0.63953488 0.00628931 0.        ]
#  [0.82051282 0.15116279 0.31446541 0.36144578]
#  [0.0974359  0.03488372 0.00628931 0.        ]]
# Computing time =  5.308765100000002  sec
#
# S= 100  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.7858508604206501
# Accuracy =  0.2141491395793499
# Confusion Error Probabilities p(class i|class j) =
#  [[0.01538462 0.         0.62893082 0.54216867]
#  [0.02051282 0.8255814  0.         0.        ]
#  [0.         0.         0.         0.        ]
#  [0.96410256 0.1744186  0.37106918 0.45783133]]
# Computing time =  3.559366499999996  sec
#
# S= 100  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.762906309751434
# Accuracy =  0.23709369024856597
# Confusion Error Probabilities p(class i|class j) =
#  [[0.53846154 0.08139535 0.0754717  0.81927711]
#  [0.         0.         0.         0.        ]
#  [0.22564103 0.90697674 0.03144654 0.01204819]
#  [0.23589744 0.01162791 0.89308176 0.1686747 ]]
# Computing time =  3.739055399999998  sec
#
# S= 100  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.9349904397705545
# Accuracy =  0.06500956022944548
# Confusion Error Probabilities p(class i|class j) =
#  [[0.05641026 0.6744186  0.08176101 0.79518072]
#  [0.02564103 0.19767442 0.88050314 0.18072289]
#  [0.91282051 0.12790698 0.03773585 0.02409639]
#  [0.00512821 0.         0.         0.        ]]
# Computing time =  4.059622999999988  sec
#
# S= 100  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.5659655831739961
# Accuracy =  0.43403441682600385
# Confusion Error Probabilities p(class i|class j) =
#  [[0.76923077 0.10465116 0.97484277 1.        ]
#  [0.23076923 0.89534884 0.02515723 0.        ]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]]
# Computing time =  4.545631900000004  sec
#
# S= 100  fold cross validation using the 100 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.6290630975143403
# Accuracy =  0.3709369024856597
# Confusion Error Probabilities p(class i|class j) =
#  [[0.99487179 0.98837209 0.97484277 0.79518072]
#  [0.00512821 0.         0.02515723 0.20481928]
#  [0.         0.01162791 0.         0.        ]
#  [0.         0.         0.         0.        ]]
# Computing time =  6.60513370000001  sec
#
# accuracy=
#  [[0.44741874 0.15678776 0.4206501  0.35755258 0.48183556]
#  [0.30592734 0.17399618 0.46080306 0.12428298 0.21988528]
#  [0.28489484 0.15678776 0.28871893 0.26959847 0.25621415]
#  [0.0707457  0.3040153  0.36711281 0.10898662 0.27724665]
#  [0.3250478  0.10133843 0.02294455 0.19502868 0.208413  ]
#  [0.21414914 0.23709369 0.06500956 0.43403442 0.3709369 ]]
#
# p_classerror=
#  [[0.55258126 0.84321224 0.5793499  0.64244742 0.51816444]
#  [0.69407266 0.82600382 0.53919694 0.87571702 0.78011472]
#  [0.71510516 0.84321224 0.71128107 0.73040153 0.74378585]
#  [0.9292543  0.6959847  0.63288719 0.89101338 0.72275335]
#  [0.6749522  0.89866157 0.97705545 0.80497132 0.791587  ]
#  [0.78585086 0.76290631 0.93499044 0.56596558 0.6290631 ]]
